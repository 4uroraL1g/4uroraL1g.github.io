# %% [markdown]
# # Assignment 1: Data Preperation and Exploration
#
# This is submission for Assignment 1 for student s3916570 - Vo Minh Thien An
#
# In this notebook, we are going to explore a dataset about bank loan for later marketing strategy,

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Task 1: Data Preparation

# %%
# import data
df = pd.read_csv('bank.txt', delimiter='\t')
# print out data
df
# Out:
#       age          job  marital          education default  housing     loan  \
# 0      30  blue-collar  married           basic.9y      no      yes       no
# 1      39     services   single        high.school      no       no       no
# 2      25     services  married        high.school      no      yes       no
# 3      38     services  married           basic.9y      no  unknown  unknown
# 4      47       admin.  married  university.degree      no      yes       no
# ...   ...          ...      ...                ...     ...      ...      ...
# 4114   30       admin.  married           basic.6y      no      yes      yes
# 4115   39       admin.  married        high.school      no      yes       no
# 4116   27      student   single        high.school      no       no       no
# 4117   58       admin.  married        high.school      no       no       no
# 4118   34   management   single        high.school      no      yes       no
#
# ...

# %% [markdown]
# We can see that there are 21 columms in the data, which mean this data have 21 different categories. And we have 4119 sample for this data, labeled from 0 to 4118.

# %%
#brief check the numeric value
df.describe()
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4119.000000  4116.000000  4117.000000  4119.000000  4119.000000
# mean     40.162661   256.838678     2.537284   960.422190     0.190337
# std      10.621359   254.745327     2.568759   191.922786     0.541788
# min      13.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.000000     3.000000   999.000000     0.000000
# max     140.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count   4117.000000     4117.000000    4117.000000  4117.000000  4119.000000
# mean       0.085183       93.579449     -40.502308     3.620728  5166.481695
# std        1.563138        0.579190       4.593059     1.733778    73.667904
# ...

# %% [markdown]
# We can see there is 0 in min duration, which mean the call was end right after they pick it up. I think it mind be erros
# And the age max is 140 which is impossible

# %% [markdown]
# I will clean the age first

# %%
df.sort_values('age')
# Out:
#       age           job   marital          education  default housing loan  \
# 100    13    management   married  university.degree  unknown      no  yes
# 98     15    management   married  university.degree       no      no   no
# 99     16        admin.   married            unknown       no      no   no
# 477    18       student    single            unknown       no      no   no
# 899    18       student    single            unknown       no     yes  yes
# ...   ...           ...       ...                ...      ...     ...  ...
# 1215   88       retired  divorced           basic.4y       no     yes  yes
# 1598   90  entrepreneur   married  university.degree       no     yes   no
# 1599   94      services  divorced        high.school       no      no   no
# 1500  138        admin.   married  university.degree       no     yes   no
# 1499  140        admin.   married        high.school  unknown     yes   no
#
# ...

# %% [markdown]
# I see that there are two people have unsual age
# This mind be the typo, with extra "1" in row number 1499 and 1500

# %%
#replace 138 and 140 with 38 and 40
#then fix the csv file
df.loc[1500,'age'] = 38
df.loc[1499,'age'] = 40
df.to_csv("bank.csv", index = False)

# %% [markdown]
# I see that there are three age value which is not match with aother value, it suppose to be a typo.
# They are value in row number 98, 99 and 100

# %%
#replace 13, 16 and 15 with 31, 61 and 51
#then fix the csv file
df.loc[100,'age'] = 31
df.loc[98,'age'] = 51
df.loc[99,'age'] = 61
df.to_csv("bank.csv", index = False)

# %%
#double check   #age from 30-40 named most
df.sort_values('age')
# Out:
#       age           job   marital          education  default housing loan  \
# 477    18       student    single            unknown       no      no   no
# 899    18       student    single            unknown       no     yes  yes
# 1661   18       student    single            unknown       no     yes   no
# 1887   19       student    single        high.school  unknown     yes   no
# 1377   20       student    single            unknown       no     yes  yes
# ...   ...           ...       ...                ...      ...     ...  ...
# 696    86       retired   married            unknown  unknown     yes  yes
# 1796   86       retired   married            unknown  unknown     yes   no
# 1215   88       retired  divorced           basic.4y       no     yes  yes
# 1598   90  entrepreneur   married  university.degree       no     yes   no
# 1599   94      services  divorced        high.school       no      no   no
#
# ...

# %% [markdown]
# After clean, the age now go from the range 18 to 94, which is acceptable

# %% [markdown]
# Then, in the next step I'll move to "job" column

# %%
df["job"].value_counts()
# Out:
# admin.           1012
# blue-collar       883
# technician        691
# services          392
# management        324
# retired           166
# self-employed     159
# entrepreneur      147
# unemployed        111
# housemaid         110
# student            82
# unknown            39
# entrepreneurs       1
# bluecollar          1
# servicess           1
# Name: job, dtype: int64

# %% [markdown]
# I see there are two "entrepreneur" value, one which 's' and one not. I'll clear the 's', because the number of the extra "s" is less than the other.

# %% [markdown]
# I see there are two "blue-collar" value, one which '-' and one not. I'll clear the one don't have '-', because the number of the extra "-" is higher than the other.

# %% [markdown]
# I see there are two "services" value, one which 'one s' and one 'double s'. I'll clear the extra 's', because the number of the extra "s" is less than the other.

# %% [markdown]
# I also see that there is a ".(dot)" after 'admin'. But they have 1012 same value like that, which mean there maybe some idea behind, so I'll remain unchange

# %%
#find the typo
print(df[df['job'].str.contains('entrepreneurs')])
# Out:
#       age            job  marital          education  default housing loan  \
# 4037   37  entrepreneurs  married  university.degree  unknown     yes   no
#
#        contact month day_of_week  duration  campaign  pdays  previous  \
# 4037  cellular   nov         mon    1012.0       1.0    999         0
#
#          poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 4037  nonexistent          -0.1            93.2          -42.0      4.191
#
#       nr.employed   y
# 4037       5195.8  no

# %%
#find the typo
print(df[df['job'].str.contains('bluecollar')])
# Out:
#       age         job   marital education  default housing loan    contact  \
# 4068   47  bluecollar  divorced  basic.9y  unknown     yes   no  telephone
#
#      month day_of_week  duration  campaign  pdays  previous     poutcome  \
# 4068   may         wed      30.0       2.0    999         0  nonexistent
#
#       emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 4068           1.1          93.994          -36.4      4.857       5191.0  no

# %%
#find the typo
print(df[df['job'].str.contains('servicess')])
# Out:
#       age        job  marital    education default housing loan    contact  \
# 4096   33  servicess  married  high.school      no      no   no  telephone
#
#      month day_of_week  duration  campaign  pdays  previous     poutcome  \
# 4096   may         mon     146.0       2.0    999         0  nonexistent
#
#       emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 4096           1.1          93.994          -36.4      4.857       5191.0  no

# %%
#fix the typo
df.loc[4096,'job'] = 'services'
df.loc[4068,'job'] = 'blue-collar'
df.loc[4037,'job'] = 'entrepreneur'
df.to_csv("bank.csv", index = False)

# %%
#double check
df["job"].value_counts()
# Out:
# admin.           1012
# blue-collar       884
# technician        691
# services          393
# management        324
# retired           166
# self-employed     159
# entrepreneur      148
# unemployed        111
# housemaid         110
# student            82
# unknown            39
# Name: job, dtype: int64

# %% [markdown]
# Thing look good now, no any value in job category have typo

# %%
df["marital"].value_counts()
# Out:
# married     2509
# single      1153
# divorced     446
# unknown       11
# Name: marital, dtype: int64

# %% [markdown]
# marital value look good

# %%
df["education"].value_counts()
# Out:
# university.degree      1264
# high.school             921
# basic.9y                572
# professional.course     535
# basic.4y                425
# basic.6y                223
# unknown                 167
# basic .6y                 4
# basic0.4y                 2
# basic .4y                 2
# basic .9y                 2
# basic0.6y                 1
# illiterate                1
# Name: education, dtype: int64

# %% [markdown]
# Can see that there are lots of typo in this category

# %% [markdown]
# We have extra white space, typo with extra "0"

# %%
#clear white space
df["education"] = df["education"].str.replace(' ', '')

# %%
#clear the extra 0
#find the three typo
print(df[df['education'].str.contains('basic0.4y')])
print(df[df['education'].str.contains('basic0.6y')])
# Out:
#     age          job  marital  education default housing loan    contact  \
# 13   47  blue-collar  married  basic0.4y      no     yes   no  telephone
# 19   50  blue-collar  married  basic0.4y      no      no  yes   cellular
#
#    month day_of_week  duration  campaign  pdays  previous     poutcome  \
# 13   jun         thu     211.0       2.0    999         0  nonexistent
# 19   jul         tue     849.0       1.0    999         0  nonexistent
#
#     emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# 13           1.4          94.465          -41.8      4.958       5228.1   no
# 19           1.4          93.918          -42.7      4.961       5228.1  yes
#     age       job  marital  education  default housing loan   contact month  \
# 20   55  services  married  basic0.6y  unknown     yes   no  cellular   jul
#
#    day_of_week  duration  campaign  pdays  previous     poutcome  \
# 20         tue     326.0       6.0    999         0  nonexistent
#
# ...

# %% [markdown]
# Can see that the mistake located at column 13, 19 and 20

# %%
#fix the typo
df.loc[13,'education'] = 'basic.4y'
df.loc[19,'education'] = 'basic.4y'
df.loc[20,'education'] = 'basic.6y'
df.to_csv("bank.csv", index = False)

# %%
#double check
df["education"].value_counts()
# Out:
# university.degree      1264
# high.school             921
# basic.9y                574
# professional.course     535
# basic.4y                429
# basic.6y                228
# unknown                 167
# illiterate                1
# Name: education, dtype: int64

# %%
df["default"].value_counts()
# Out:
# no         3315
# unknown     803
# yes           1
# Name: default, dtype: int64

# %% [markdown]
# It look clean, no any mistake

# %%
df["housing"].value_counts()
# Out:
# yes        2172
# no         1835
# unknown     105
# Yes           2
# No            2
# na            1
# Name: housing, dtype: int64

# %% [markdown]
# Can see that there are 5 mistake, mostly typo

# %%
#solve the typo
df["housing"] = df["housing"].str.replace('Y', 'y')
df["housing"] = df["housing"].str.replace('N', 'n')
df["housing"] = df["housing"].str.replace('a', 'o')

# %%
#double check
df["housing"].value_counts()
# Out:
# yes        2174
# no         1838
# unknown     105
# Name: housing, dtype: int64

# %%
df["loan"].value_counts()
# Out:
# no         3346
# yes         665
# unknown     105
# na            3
# Name: loan, dtype: int64

# %% [markdown]
# Can see there are three "na" values, assume that "na" is typo of "no"

# %%
#solve the typo
df["loan"] = df["loan"].str.replace('a', 'o')

# %%
#double check
df["loan"].value_counts()
# Out:
# no         3349
# yes         665
# unknown     105
# Name: loan, dtype: int64

# %%
df["contact"].value_counts()
# Out:
# cellular       2650
# telephone      1466
#  telephone        1
# cellular          1
#   cellular        1
# Name: contact, dtype: int64

# %% [markdown]
# Extra white space

# %%
#clear white space
df["contact"] = df["contact"].str.replace(' ', '')

# %%
#double check
df["contact"].value_counts()
# Out:
# cellular     2652
# telephone    1467
# Name: contact, dtype: int64

# %%
df["month"].value_counts()
# Out:
# may    1378
# jul     711
# aug     636
# jun     530
# nov     446
# apr     215
# oct      69
# sep      64
# mar      48
# dec      22
# Name: month, dtype: int64

# %%
df["day_of_week"].value_counts()
# Out:
# thu       860
# mon       854
# tue       841
# wed       795
# fri       767
# Monday      1
# Friday      1
# Name: day_of_week, dtype: int64

# %% [markdown]
# We have "Monday", and "Friday" not in the right format

# %%
#solve problem and check again
df["day_of_week"] = df["day_of_week"].str.replace('Monday', 'mon')
df["day_of_week"] = df["day_of_week"].str.replace('Friday', 'fri')
df['day_of_week'].value_counts()
# Out:
# thu    860
# mon    855
# tue    841
# wed    795
# fri    768
# Name: day_of_week, dtype: int64

# %%
#there are value "0" in duration, which mean the value in column "Y" must be "no"
#there are some nan value in duration
df.sort_values('duration')
# Out:
#       age            job   marital            education  default housing loan  \
# 1950   39         admin.   married          high.school       no     yes   no
# 1600   28  self-employed    single             basic.9y       no     yes   no
# 2534   57         admin.  divorced    university.degree       no      no   no
# 1896   30  self-employed    single             basic.9y       no      no  yes
# 934    31    blue-collar    single             basic.9y       no     yes   no
# ...   ...            ...       ...                  ...      ...     ...  ...
# 1546   46         admin.  divorced          high.school       no     yes   no
# 2231   31     technician   married  professional.course       no      no   no
# 82     59       services   married             basic.4y  unknown      no   no
# 254    25     technician    single    university.degree       no     yes  yes
# 299    28     unemployed    single    university.degree       no     yes   no
#
# ...

# %% [markdown]
# After brief check through a description, and the dataframe. Can confirm that the value "0" is acceptable

# %%
df['campaign'].value_counts()
# Out:
# 1.0     1764
# 2.0     1038
# 3.0      548
# 4.0      291
# 5.0      142
# 6.0       99
# 7.0       60
# 8.0       36
# 9.0       32
# 10.0      20
# 11.0      19
# 12.0      16
# 17.0      14
# 13.0      11
# 16.0       7
# 14.0       6
# 15.0       2
# 22.0       2
# 19.0       2
# 23.0       2
# 29.0       2
# 27.0       1
# 18.0       1
# 24.0       1
# 35.0       1
# Name: campaign, dtype: int64

# %%
df['pdays'].value_counts()
# Out:
# 999    3959
# 3        52
# 6        42
# 4        14
# 7        10
# 10        8
# 12        5
# 5         4
# 2         4
# 1         3
# 9         3
# 16        2
# 13        2
# 18        2
# 0         2
# 15        2
# 19        1
# 17        1
# 11        1
# 21        1
# 14        1
# Name: pdays, dtype: int64

# %%
df['previous'].value_counts()
# Out:
# 0    3523
# 1     475
# 2      78
# 3      25
# 4      14
# 5       2
# 6       2
# Name: previous, dtype: int64

# %%
df['emp.var.rate'].value_counts()
# Out:
#  1.4    1626
# -1.8     882
#  1.1     757
# -0.1     392
# -2.9     164
# -3.4     104
# -1.7      87
# -1.1      83
# -3.0      21
# -0.2       1
# Name: emp.var.rate, dtype: int64

# %%
df['cons.price.idx'].value_counts()
# Out:
# 93.994    758
# 93.918    667
# 92.893    597
# 93.444    527
# 94.465    431
# 93.200    386
# 93.075    201
# 92.963     75
# 92.201     75
# 92.431     43
# 94.199     39
# 92.649     36
# 94.027     33
# 94.215     30
# 92.379     25
# 92.843     25
# 94.055     24
# 93.369     23
# 94.767     23
# 93.876     23
# 92.713     21
# 94.601     20
# 93.749     14
# 92.469     14
# 93.798      6
# 92.756      1
# Name: cons.price.idx, dtype: int64

# %%
df['cons.conf.idx'].value_counts()
# Out:
# -36.4    757
# -42.7    667
# -46.2    597
# -36.1    528
# -41.8    431
# -42.0    386
# -47.1    201
# -40.8     75
# -31.4     74
# -26.9     43
# -37.5     39
# -30.1     36
# -38.3     33
# -40.3     30
# -29.8     25
# -50.0     25
# -39.8     24
# -50.8     24
# -34.8     23
# -40.0     23
# -33.0     21
# -49.5     20
# -34.6     14
# -33.6     14
# -40.4      6
# -45.9      1
# Name: cons.conf.idx, dtype: int64

# %%
df['euribor3m'].value_counts()
# Out:
# 4.857    274
# 4.963    256
# 4.962    237
# 4.961    212
# 4.856    138
#         ...
# 0.889      1
# 4.343      1
# 0.749      1
# 3.329      1
# 0.965      1
# Name: euribor3m, Length: 234, dtype: int64

# %%
df['nr.employed'].value_counts()
# Out:
# 5228.1    1626
# 5099.1     823
# 5191.0     758
# 5195.8     392
# 5076.2     164
# 5017.5     104
# 4991.6      87
# 4963.6      83
# 5008.7      60
# 5023.5      21
# 5176.3       1
# Name: nr.employed, dtype: int64

# %%
df['y'].value_counts()
# Out:
# no     3668
# yes     451
# Name: y, dtype: int64

# %% [markdown]
# The value in these category look normal, assume that there are no error here

# %%
df['poutcome'].value_counts()
# Out:
# nonexistent      3521
# failure           454
# success           142
# nonexistent         1
#   nonexistent       1
# Name: poutcome, dtype: int64

# %%
#clear white space
df["poutcome"] = df["poutcome"].str.replace(' ', '')

# %%
#double check
df['poutcome'].value_counts()
# Out:
# nonexistent    3523
# failure         454
# success         142
# Name: poutcome, dtype: int64

# %%
#save all the final results to a file
df.to_csv("bank.csv", index = False)

# %%
#NaN check
df.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           2
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          3
# campaign          2
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      2
# cons.price.idx    2
# cons.conf.idx     2
# euribor3m         2
# nr.employed       0
# y                 0
# dtype: int64

# %% [markdown]
# # Task 3:Dealing with Missing Values and Outliers

# %% [markdown]
# First way: Can see that the missing value is not take a large part in the dataframe. So that I'll fill all the missing value by delete any rows with 'NaN' value

# %%
df_delete_NaN = pd.read_csv(r'bank_delete_NaN.csv')
df_delete_NaN = df

# %%
df_delete_NaN.dropna(inplace = True)

# %% [markdown]
# Second way: In this way I'll use the valuie in next row to fill in missing value. By doing this I can have more value than just delete it, and the value will more accurate than just replace it with random value.

# %%
df_fill_next = pd.read_csv(r'bank_fill_next.csv')
df_fill_next = df

# %%
df_fill_next.fillna(method = 'bfill')
# Out:
#       age          job  marital          education default  housing     loan  \
# 0      30  blue-collar  married           basic.9y      no      yes       no
# 1      39     services   single        high.school      no       no       no
# 2      25     services  married        high.school      no      yes       no
# 3      38     services  married           basic.9y      no  unknown  unknown
# 4      47       admin.  married  university.degree      no      yes       no
# ...   ...          ...      ...                ...     ...      ...      ...
# 4114   30       admin.  married           basic.6y      no      yes      yes
# 4115   39       admin.  married        high.school      no      yes       no
# 4116   27      student   single        high.school      no       no       no
# 4117   58       admin.  married        high.school      no       no       no
# 4118   34   management   single        high.school      no      yes       no
#
# ...

# %% [markdown]
# third way: In this way I'll use the valuie in next row to fill in missing value. By doing this I can have more value than just delete it, and the value will more accurate than just replace it with random value.

# %%
df_fill_pre = pd.read_csv(r'bank_fill_pre.csv')
df_fill_pre = df

# %%
df_fill_pre.fillna(method = 'pad')
# Out:
#       age          job  marital          education default  housing     loan  \
# 0      30  blue-collar  married           basic.9y      no      yes       no
# 1      39     services   single        high.school      no       no       no
# 2      25     services  married        high.school      no      yes       no
# 3      38     services  married           basic.9y      no  unknown  unknown
# 4      47       admin.  married  university.degree      no      yes       no
# ...   ...          ...      ...                ...     ...      ...      ...
# 4114   30       admin.  married           basic.6y      no      yes      yes
# 4115   39       admin.  married        high.school      no      yes       no
# 4116   27      student   single        high.school      no       no       no
# 4117   58       admin.  married        high.school      no       no       no
# 4118   34   management   single        high.school      no      yes       no
#
# ...

# %% [markdown]
# These two way is inspired by geeksforgeeks, code2 and code3
# https://www.geeksforgeeks.org/working-with-missing-data-in-pandas/

# %% [markdown]
# All data that I have found and changed </p> </p>
# #1 In "age" there is typo at row number 98, 99, 100, 1499, 1500. All five mistakes make illogic</p>
# #2 In "job" there is typo at row number 4037, 4068, 4096</p>
# #3 In "education" which have extra white space and typo. Typo at row number 13, 19, 20</p>
# #4 In "housing" is typo which is wrong uppercase and wrong word character and "NaN" value (missing value)</p>
# #5 In "loan" is typo which is wrong word character</p>
# #6 In "contact" is extra white space</p>
# #7 In "day_of_week" is wrong day format</p>
# #8 In "poutcome" is extra white space</p>
# #9 In "emp.var.rate" is "NaN" value (missing value)</p>
# #10 In "cons.conf.idx" is "NaN" value (missing value)</p>
# #11 In "cons.price.idx" is "NaN" value (missing value)</p>
# #12 In "euribor3m" is "NaN" value (missing value)</p>
# #13 In "campaign" is "NaN" value (missing value)</p>
# #14 In "duration" is "NaN" value (missing value)</p>

# %% [markdown]
# # Task 2: Data Exploration

# %%
import matplotlib.pyplot as plt

# %%
#task 2.1

# %%
#draw a pie chart with education level value
df['education'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='education'>

# %% [markdown]
# I choose education level, which is ordinal value to draw a pie chart because it can show clearly the amount of people who have done high school or higher is much more than people who only did basic study. </p>
# And in this pie chart we can see that the amount of people with good education level is higher than the other with low education level

# %% [markdown]
# And also, pie chart is the most suitable chart to display this kind of value

# %% [markdown]
# This pie chart show us that the campaign aim mostly to people with high education level, which mean there are more chance they will join the campaign.

# %%
#draw bar chart with "age" value
df['age'].plot(kind='hist',bins=70) 
plt.title('Average user age')
plt.xlabel('age')
# Out:
# Text(0.5, 0, 'age')

# %% [markdown]
# I choose age, which is numerical value to draw a bar chart because it can show the trend/the age that suitable the most with this campaign. For this kind of value we need a chart that can show us two values, which is bar chart or line chart.  </p> </p>
# We can see the aim is people from 25 to 55 or 60, this is the age that people want to work more and have more accumulation to prepare themself from retire age. So they will tend to accept the campaign or the loan to self growth to as high as they could. </p>
# People in the age higher than 60 is opposite, they want to be safe, enjoy their life. So it will hard to invite them to a new loan or campaign

# %%
#draw a pie chart with month level value
df['month'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='month'>

# %% [markdown]
# I choose month, which is nominal value to draw a pie chart. I choose this category because it can show the different in number of people want to loan. By this we can predict something will happen in around specific time </p> </p>
# Can see that number in may is incredibly high which also lead to june and july, we can assume that there is something happen around this time.

# %%
#task 2.2

# %% [markdown]
# # first pair

# %% [markdown]
# The first pair I choose is education level and default</p>
# Hypothesis: The "high education" group have the potential in pay and loan more than the "low level of education" group </p>
# While default shows customer's credit in default, the education level shows how you did your study.
# If we look at the first pie chart at high education(from basic 9 year to professional) and other is low education. We can see that these two charts have the same patent.</p>
# Both high education and no credit in default take nearly 80% of the chart.
# Then we can make a hypothesis that these 80% are easier to pay for their loan and loan back once again than the other 20%, because of that we should aim for this group to make a marketing plan.

# %%
plt.figure(0)
df['education'].value_counts().plot(kind='pie',autopct='%.2f')
plt.figure(1)
df['default'].value_counts().plot(kind='pie',autopct='%.2f')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Second pair

# %% [markdown]
# In this second pair I choose Job and cons.conf.idx as know as consumer confidence index to draw a boxplot
# </p>Hypothesis: There can be a pandemic going through.
# </p>While consumer confidence index help me to know how customer think about their life now and 6 month later
# And it is separated by job, which means this happens in all people with a variety of jobs.
# </p>We can see that all the index is negative, which means there is something happening in this time period that makes everybody feel uncomfortable about their life. If you combine this with the consumer price index, which is lower than 100.</p> We can say that mind be a pandemic have undergo through a pandemic which make the increase in the supply and decrease in living condition

# %%
df.dropna().boxplot(column='cons.conf.idx',by='job')
plt.show()

# %% [markdown]
# # third pair

# %% [markdown]
# In the third pair I choose 'pdays' and 'poutcome' which can show us the success of the previous marketing plan.
#
# Hypothesis: The previous marketing plan was not successful
# These two column show us that the previous marketing campaign did not bring good outcome
#
# We can see the value '999' in 'pdays', which means that the client was not contacted since the last marketing campaign, things go the same in 'poutcome' more than 80% outcome is nonexist, other 10% is failure.
# which these two chart we can assume that the previous marketing plan was not success, we need to find the reason and fix it if we immediately to gain success.

# %%
plt.figure(0)
df['pdays'].value_counts().plot(kind='pie',autopct='%.2f')
plt.figure(1)
df['poutcome'].value_counts().plot(kind='pie',autopct='%.2f')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#task 2.3

# %%
from pandas.plotting import scatter_matrix

# %%
age = df["age"]
previous = df["previous"]
campaign = df["campaign"]
df_matrix = pd.DataFrame({'age':age, 'previous':previous, 'campaign':campaign})
df_matrix.head()
# Out:
#    age  previous  campaign
# 0   30         0       2.0
# 1   39         0       4.0
# 2   25         0       1.0
# 3   38         0       3.0
# 4   47         0       1.0

# %%
pd.plotting.scatter_matrix(df_matrix)
# Out:
# array([[<AxesSubplot:xlabel='age', ylabel='age'>,
#         <AxesSubplot:xlabel='previous', ylabel='age'>,
#         <AxesSubplot:xlabel='campaign', ylabel='age'>],
#        [<AxesSubplot:xlabel='age', ylabel='previous'>,
#         <AxesSubplot:xlabel='previous', ylabel='previous'>,
#         <AxesSubplot:xlabel='campaign', ylabel='previous'>],
#        [<AxesSubplot:xlabel='age', ylabel='campaign'>,
#         <AxesSubplot:xlabel='previous', ylabel='campaign'>,
#         <AxesSubplot:xlabel='campaign', ylabel='campaign'>]], dtype=object)

# %% [markdown]
# # Task3 draw a chart after deal with missing value

# %%
df_delete_NaN['housing'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='housing'>

# %%
df_fill_next['housing'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='housing'>

# %%
df_fill_pre['housing'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='housing'>
